# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/source/code

# %%
# !python3 train.py -c config/vessel/u2net3d.json -tbs 5 -vbs 5
# Out:
# 2020-09-19 16:46:31.957744: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Config info
# - Model file name: u2net3d - main
# - Trained model is saved at /content/drive/My Drive/source/code/saved/u2net3d/0919_main
# - Dataset path: /dataset/data6496/train
#
# DataLoader
# + Batch size: 5
# + Train set's size: 1000 batch
# Config model
# Loss: FocalLoss
#  - param: OrderedDict([('gamma', 2.0), ('alpha', 0.8)])
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: True
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0005
#     weight_decay: 0
# )
# Model: U2net3D
#  - param: OrderedDict([('in_channels', 1), ('out_channels', 1), ('depth', 4), ('is_bn', True), ('is_res', True), ('drop_rate', 0.4)])
#
# U2net3D(
#   (activation): Sigmoid()
#   (maxpool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (first_block): Sequential(
#     (conv_0): ConvBlock(
# ...

# %%
# !python3 train.py -r saved/u2net3dv21/v21_d4_start32/models/checkpoint-epoch25.pth

# %%
# !nvidia-smi
